# %%
import pandas as pd
import os
import gc
from datetime import datetime, timedelta

# %%
holidays = [
  "20230126",
  "20230307",
  "20230330",
  "20230404",
  "20230407",
  "20230414",
  "20230501",
  "20230628",
  "20230815",
  "20230919",
  "20231002",
  "20231024",
  "20231114",
  "20231127",
  "20231225"
]

# %%
def isHoliday(date:datetime):
    pass

# %%
folder_path = '/home/cloudcraftz/Documents/ZIPPED (1)/object_store/backtest/'

pnl = 0

for filename in os.listdir(folder_path):
    if os.path.isfile(os.path.join(folder_path, filename)):
        if filename.endswith('.csv'):
            absolute_path = os.path.abspath(os.path.join(folder_path, filename))
            date_str = filename.split('.')[0]


            date_obj = datetime.strptime(date_str, '%Y%m%d')

            if date_obj.weekday() == 3:
                if date_str in holidays:
                    date_obj -= timedelta(days=1)
                df = pd.read_csv(absolute_path)

                pnl += df['Values'].iloc[-1]

                del df
                gc.collect()

# %%
pnl
# Out:
# 9325284.156067565

# %%
import yfinance as yf

# Define the ticker symbol for SBIN
ticker = "^SBIN.NS"  # '.NS' is for NSE (National Stock Exchange of India)

# Download OHLC data for 2024
df = yf.download(ticker, start="2024-01-01", end="2025-01-01", interval="1d")

# Display the first few rows
print(df.head())

# Save to CSV if needed
df.to_csv("SBIN_OHLC_2024.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['^SBIN.NS']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, ^SBIN.NS), (Close, ^SBIN.NS), (High, ^SBIN.NS), (Low, ^SBIN.NS), (Open, ^SBIN.NS), (Volume, ^SBIN.NS)]
# Index: []
