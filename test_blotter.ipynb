# %%
import pandas as pd
from glob import glob

# %%
Blotter_file_list = glob("/home/cloudcraftz/Office_Projects/10_Fintech/backtest_2.0_dev/HFT-Options-EIS-Global/tradelib/outputs/NF_SMA_CROSS_OVER/2024_NIFTY_SMA_STRADDLE_STRATEGY_fast_25_slow_40_tol_0/blotter/*.csv")

Blotter_bt_df_list = [pd.read_csv(i) for i in Blotter_file_list]

Blotter_df = pd.concat(Blotter_bt_df_list, ignore_index=True)
# Blotter_df = Blotter_df[Blotter_df['trade_done']==True]
Blotter_df['timestamp'] = pd.to_datetime(Blotter_df['timestamp'])
Blotter_df = Blotter_df.set_index("timestamp", drop=True)
Blotter_df = Blotter_df.sort_index()

# %%
Blotter_df[Blotter_df['trade_sub_type']=='trade'].loc['2024-01-01']
# Out:
#                      trade_id  packet_id  component_trade_id  \
# timestamp
# 2024-01-01 09:59:00         1          1                   1
# 2024-01-01 09:59:00         2          1                   1
# 2024-01-01 11:26:00       123         62                   2
# 2024-01-01 11:26:00       124         62                   2
# 2024-01-01 11:39:00       127         64                   3
# 2024-01-01 11:39:00       128         64                   3
# 2024-01-01 11:40:00       132         66                   4
# 2024-01-01 11:40:00       131         66                   4
# 2024-01-01 11:41:00       135         68                   5
# 2024-01-01 11:41:00       136         68                   5
# 2024-01-01 12:43:00       220        110                   6
# 2024-01-01 12:43:00       219        110                   6
# 2024-01-01 12:54:00       224        112                   7
# 2024-01-01 12:54:00       223        112                   7
# 2024-01-01 14:10:00       329        165                   8
# 2024-01-01 14:10:00       330        165                   8
# 2024-01-01 14:39:00       338        169                   9
# 2024-01-01 14:39:00       337        169                   9
# 2024-01-01 14:55:00       365        183                  10
# 2024-01-01 14:55:00       366        183                  10
#
#                             trade_component  instrument_id  \
# timestamp
# 2024-01-01 09:59:00  sma_straddle_component          42214
# 2024-01-01 09:59:00  sma_straddle_component          42215
# 2024-01-01 11:26:00  sma_straddle_component          42214
# 2024-01-01 11:26:00  sma_straddle_component          42215
# 2024-01-01 11:39:00  sma_straddle_component          42214
# 2024-01-01 11:39:00  sma_straddle_component          42215
# 2024-01-01 11:40:00  sma_straddle_component          42215
# 2024-01-01 11:40:00  sma_straddle_component          42214
# 2024-01-01 11:41:00  sma_straddle_component          42214
# 2024-01-01 11:41:00  sma_straddle_component          42215
# 2024-01-01 12:43:00  sma_straddle_component          42215
# 2024-01-01 12:43:00  sma_straddle_component          42214
# 2024-01-01 12:54:00  sma_straddle_component          42218
# 2024-01-01 12:54:00  sma_straddle_component          42216
# 2024-01-01 14:10:00  sma_straddle_component          42227
# 2024-01-01 14:10:00  sma_straddle_component          42229
# 2024-01-01 14:39:00  sma_straddle_component          42229
# 2024-01-01 14:39:00  sma_straddle_component          42227
# 2024-01-01 14:55:00  sma_straddle_component          42230
# 2024-01-01 14:55:00  sma_straddle_component          42231
#
#                           instrument_id_key   position   price trade_sub_type  \
# timestamp
# 2024-01-01 09:59:00  NIFTY_21750_CE_20240104   -5000.0  126.50          trade
